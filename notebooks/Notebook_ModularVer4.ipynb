# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from scipy import ndimage
import glob

RAW_PATH = Path('../data/raw/Original')
CLASSES  = ['Benign', 'Early', 'Pre', 'Pro']
COLORES  = {'Benign': '#2ecc71', 'Early': '#e74c3c', 'Pre': '#e67e22', 'Pro': '#9b59b6'}

print('Librerías cargadas OK')
# Out:
# Librerías cargadas OK

# %%
from pathlib import Path
import cv2

def obtener_rutas_imagenes():
    """
    Carga todas las imágenes válidas de data/raw/Original
    """
    RAW_PATH = Path('c:/ProyectoPSIB/leukemia-detection-all-idb/data/raw/Original')
    CLASES   = ['Benign', 'Early', 'Pre', 'Pro']

    dataset = {}
    for cls in CLASES:
        carpeta = RAW_PATH / cls
        imgs = list(carpeta.glob('*.jpg')) + list(carpeta.glob('*.png'))
        imgs_validas = []
        for p in imgs:
            img = cv2.imread(str(p))
            if img is not None and img.mean() >= 5:
                imgs_validas.append(p)
        dataset[cls] = imgs_validas

    todas = [p for paths in dataset.values() for p in paths]

    print('Dataset cargado:')
    for cls, imgs in dataset.items():
        print(f'  {cls:<10}: {len(imgs)} imágenes')
    print(f'  {"Total":<10}: {len(todas)} imágenes')

    return dataset, todas

# %%
import cv2
from pathlib import Path

def guardar_imagen_resultado(imagen, ruta_original, carpeta_resultados='../data/resultados/Notebook2/'):
    """
    Guarda la imagen procesada en data/resultados/Notebook2/
    manteniendo la estructura de subcarpetas por clase (Benign, Early, Pre).
    Soporta imágenes RGB a color y máscaras en blanco y negro.
    """
    ruta_original   = Path(ruta_original)
    clase           = ruta_original.parent.name   # ej: 'Benign'
    nombre_archivo  = ruta_original.name          # ej: 'Im001_1.jpg'

    carpeta_destino = Path(carpeta_resultados) / clase
    carpeta_destino.mkdir(parents=True, exist_ok=True)

    ruta_guardado = carpeta_destino / nombre_archivo

    if len(imagen.shape) == 3:  # imagen a color (RGB → BGR para OpenCV)
        imagen_bgr = cv2.cvtColor(imagen, cv2.COLOR_RGB2BGR)
        cv2.imwrite(str(ruta_guardado), imagen_bgr)
    else:  # máscara en blanco y negro
        cv2.imwrite(str(ruta_guardado), imagen)

    return ruta_guardado

# %%
def preprocesamiento(img_path, filtro='mediana', ksize=5):
    """
    Pipeline completo de preprocesamiento:
      1. Carga imagen
      2. Convierte a HSV y extrae canal S
      3. Aplica filtro de ruido mediana
    Retorna: imagen original RGB, canal S sin procesar, canal S preprocesado
    """
    img_bgr = cv2.imread(str(img_path))
    
    # Seguro por si alguna ruta se rompe en otra compu
    if img_bgr is None:
        raise FileNotFoundError(f"No se encontró la imagen en: {img_path}")
    

    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_hsv = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2HSV)
    canal_s = img_hsv[:,:,1] # Canal S (Saturación - Índice 1)

    if filtro == 'mediana':
        canal_filtrado = cv2.medianBlur(canal_s, ksize)
    elif filtro == 'gaussiano':
        canal_filtrado = cv2.GaussianBlur(canal_s, (ksize, ksize), 0)
    else:
        canal_filtrado = canal_s
        print(f"Filtro '{filtro}' no reconocido. Se devuelve el canal S limpio.")
    
    return img_rgb, canal_s, canal_filtrado

def refinar_mascara_nucleo(mascara, kernel_size=5):
    """
    Aplica operaciones morfológicas para limpiar la máscara del núcleo:
    1. Apertura: elimina pequeños artefactos y puentes finos.
    2. Cierre: rellena huecos internos en el núcleo.
    3. Relleno de agujeros con SciPy: consolida la máscara final.
    """
    # Usamos un elemento estructurante elíptico (ideal para formas redondeadas de núcleos)
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    
    # 1. Apertura (Erosión + Dilatación) - Limpia ruidos externos
    apertura = cv2.morphologyEx(mascara, cv2.MORPH_OPEN, kernel)
    
    # 2. Cierre (Dilatación + Erosión) - Conecta componentes del mismo núcleo
    cierre = cv2.morphologyEx(apertura, cv2.MORPH_CLOSE, kernel)
    
    # 3. Relleno de agujeros internos (SciPy ndimage)
    relleno = ndimage.binary_fill_holes(cierre).astype(np.uint8) * 255
    
    # Retornamos los pasos intermedios para tu gráfico de visualización, 
    # siendo 'relleno' el resultado final optimizado.
    return apertura, cierre, relleno


def cargar_imagen(ruta):
    """Carga la imagen y devuelve versiones BGR (para OpenCV) y RGB (para matplotlib)."""
    img_bgr = cv2.imread(ruta)
    if img_bgr is None:
        raise ValueError(f"No se pudo cargar la imagen en la ruta: {ruta}")
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    return img_bgr, img_rgb


def aislar_celula(img_rgb, mask):
    """
    Multiplica la máscara por la imagen original para dejar solo la célula y el fondo negro.
    """
    # cv2.bitwise_and aplica la máscara a la imagen a color
    celula_aislada = cv2.bitwise_and(img_rgb, img_rgb, mask=mask)
    return celula_aislada

def segmentar_celula_otsu(canal_proc, umbral_maximo=45):
    # 1. Aplicamos el método de Otsu normal
    umbral_real, mask_otsu = cv2.threshold(canal_proc, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    
    # Aplicamos tu "freno de mano" por si Otsu se va muy alto
    if umbral_real > umbral_maximo:
        _, mask_otsu = cv2.threshold(canal_proc, umbral_maximo, 255, cv2.THRESH_BINARY)
        
    # ==========================================================
    # 2. MORFOLOGÍA MATEMÁTICA ASIMÉTRICA (SEPARAR Y EXPANDIR)
    # ==========================================================
    # Creamos pinceles (kernels) redondos porque las células son circulares
    kernel_romper = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (7, 7))
    kernel_expandir = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (9, 9)) # ¡Más grande!
    
    # PASO A (Erosión): "Comemos" los bordes de todas las células. 
    # Esto debilita y rompe la unión en el medio de las células siamesas.
    # Si notas que siguen pegadas en algunas fotos, sube iterations a 3.
    mask_erosionada = cv2.erode(mask_otsu, kernel_romper, iterations=2)
    
    # PASO B (Dilatación): Volvemos a inflar los pedazos que sobrevivieron.
    # Como usamos un kernel de 9x9 (mayor al de 7x7), la célula final quedará 
    # separada de su vecina, pero será ligeramente MÁS GRANDE que la original.
    mask_separada = cv2.dilate(mask_erosionada, kernel_expandir, iterations=2)
    
    return mask_separada, umbral_real

# %%
# --- 1. CARGA DE IMAGEN ---
# ¡Asegúrate de cambiar este nombre por el de una de tus imágenes de prueba!
cls = 'Benign'  # Cambia esto por 'Early', 'Pre' o 'Pro' para probar otras clases
ruta_imagen = list((RAW_PATH / cls).glob('*.jpg'))[0]  # Tomamos la primera imagen de la clase seleccionada

img_bgr, img_rgb = cargar_imagen(ruta_imagen)

# Paso A: Preprocesamiento (Tu pipeline del Canal S)
img_rgb, canal_s_raw, canal_proc = preprocesamiento(ruta_imagen, filtro='mediana', ksize=5)
    
# Paso B: Segmentación con el NUEVO freno de mano en 70
mask_raw, umbral_calc = segmentar_celula_otsu(canal_proc, umbral_maximo=45)
    
# Paso C: Refinamiento morfológico con el kernel elíptico
apertura, cierre, relleno = refinar_mascara_nucleo(mask_raw, kernel_size=5)
# --- 2. APLICAR MÉTODOS ---
# Otsu

resultado_otsu = aislar_celula(img_rgb, mask_raw)

# --- 3. MOSTRAR RESULTADOS ---
fig, axs = plt.subplots(2, 3, figsize=(18, 10))

# Fila 1: Otsu
axs[0, 0].imshow(img_rgb)
axs[0, 0].set_title("Imagen Original")
axs[0, 0].axis('off')

axs[0, 1].imshow(mask_raw, cmap='gray')
axs[0, 1].set_title("Máscara Otsu Limpia")
axs[0, 1].axis('off')

axs[0, 2].imshow(resultado_otsu)
axs[0, 2].set_title("Célula Aislada (Original x Otsu)")
axs[0, 2].axis('off')



plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def clasificar_y_filtrar_linfocitos(mascara_celula, mascara_nucleo, imagen_original, area_minima=100, area_maxima=1000):
    # ==========================================
    # 1. PARCHE DE SEGURIDAD (Evita errores de OpenCV)
    # ==========================================
    mascara_celula = np.array(mascara_celula, dtype=np.uint8)
    if mascara_celula.max() == 1: mascara_celula *= 255
        
    mascara_nucleo = np.array(mascara_nucleo, dtype=np.uint8)
    if mascara_nucleo.max() == 1: mascara_nucleo *= 255
        
    # ==========================================
    # 2. INICIO DE LA FUNCIÓN
    # ==========================================
    contornos_celula, _ = cv2.findContours(mascara_celula, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    mascara_linfocitos = np.zeros_like(mascara_celula)
    caracteristicas_extraidas = []
    
    imagen_gris = cv2.cvtColor(imagen_original, cv2.COLOR_RGB2GRAY)
    
    for cnt in contornos_celula:
        area_celula = cv2.contourArea(cnt)
        
        # ==========================================
        # FILTRO DE ÁREA (Parametrizado)
        # ==========================================
        if area_celula < area_minima or area_celula > area_maxima:
            continue
            
        perimetro_celula = cv2.arcLength(cnt, True)
        if perimetro_celula == 0: continue
            
        circularidad_celula = 4 * np.pi * (area_celula / (perimetro_celula * perimetro_celula))
        hull_celula = cv2.convexHull(cnt)
        solidez_celula = area_celula / float(cv2.contourArea(hull_celula)) if cv2.contourArea(hull_celula) > 0 else 0
        
        # --- ANÁLISIS DEL NÚCLEO ---
        mask_esta_celula = np.zeros_like(mascara_celula)
        cv2.drawContours(mask_esta_celula, [cnt], -1, 255, thickness=cv2.FILLED)
        
        nucleo_aislado = cv2.bitwise_and(mascara_nucleo, mascara_nucleo, mask=mask_esta_celula)
        contornos_nuc, _ = cv2.findContours(nucleo_aislado, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        
        if len(contornos_nuc) == 0: continue 
            
        cnt_nucleo = max(contornos_nuc, key=cv2.contourArea)
        area_nuc = cv2.contourArea(cnt_nucleo)
        peri_nuc = cv2.arcLength(cnt_nucleo, True)
        
        circularidad_nucleo = 4 * np.pi * (area_nuc / (peri_nuc * peri_nuc)) if peri_nuc > 0 else 0
        
        hull_nuc = cv2.convexHull(cnt_nucleo)
        solidez_nucleo = area_nuc / float(cv2.contourArea(hull_nuc)) if cv2.contourArea(hull_nuc) > 0 else 0
        
        # --- TEXTURA ---
        media_color, std_color = cv2.meanStdDev(imagen_gris, mask=nucleo_aislado)
        textura_nucleo = std_color[0][0] if std_color is not None else 0
            
        # --- REGLA DE ORO ---
        es_linfocito = (solidez_nucleo > 0.8) and (circularidad_nucleo > 0.65)
        
        if es_linfocito:
            cv2.drawContours(mascara_linfocitos, [cnt], -1, 255, thickness=cv2.FILLED)
            caracteristicas_extraidas.append({
                'Area_Celula': area_celula,
                'Solidez_Nuc': round(solidez_nucleo, 2),
                'Circ_Nuc': round(circularidad_nucleo, 2),
                'Textura_Nuc': round(textura_nucleo, 2)
            })
            
    img_limpia = cv2.bitwise_and(imagen_original, imagen_original, mask=mascara_linfocitos)
    return mascara_linfocitos, img_limpia, caracteristicas_extraidas

# %%
def segmentar_nucleo_estricto(canal_proc):
    """Genera la máscara marcando solo los núcleos usando el método de Otsu original.
    Ideal para medir luego la circularidad del núcleo y descartar neutrófilos.
    """
    # 1. Otsu matemático normal (encuentra lo más oscuro/saturado por sí solo)
    umbral_otsu, mascara_nucleo = cv2.threshold(
        canal_proc, 0, 255, 
        cv2.THRESH_BINARY + cv2.THRESH_OTSU
    )
    
    # 2. Pequeño cierre morfológico para que el núcleo no tenga "agujeros" negros adentro
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
    mascara_nucleo_limpia = cv2.morphologyEx(mascara_nucleo, cv2.MORPH_CLOSE, kernel)
    
    return mascara_nucleo_limpia

# %%
# Suponiendo que 'mask_raw' es la máscara que salió de Otsu 
# 'img_rgb' es tu imagen original a color
# y 'mascara_nucleos' es tu máscara de núcleos unicamente

mascara_nucleos = segmentar_nucleo_estricto(canal_proc)

mascara_filtrada, img_limpia, datos = clasificar_y_filtrar_linfocitos(mask_raw, mascara_nucleos, img_rgb)

mascara_filtrada

# Mostrar el resultado de la limpieza
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

axs[0].imshow(img_rgb)
axs[0].set_title("Imagen Original")
axs[0].axis('off')

axs[1].imshow(mascara_filtrada, cmap='gray')
axs[1].set_title(f"Máscara Final ({len(datos)} Linfocitos detectados)")
axs[1].axis('off')

axs[2].imshow(img_limpia)
axs[2].set_title("Solo Linfocitos Aislados")
axs[2].axis('off')

plt.show()

# Ver los datos matemáticos extraídos
df_celulas = pd.DataFrame(datos)
print(df_celulas)
# Out:
#    Area_Celula  Solidez_Nuc  Circ_Nuc  Textura_Nuc
# 0        221.0         0.98      0.77        29.08
# 1        555.5         0.98      0.82        13.74
# 2        527.0         0.92      0.66        15.79
# 3        531.5         0.97      0.85        23.74
# 4        307.0         0.98      0.88        19.50

# %%
"Comentarios:"
"- Falta agregar una forma para cuando hay celulas muy pegadas las diferencie. "
"porque al tomar las 2 juntas la funcion clasificar_y_filtrar_linfocitos no elimina las mas chicas que "
"esten pegadas a un linfocito "

"- Falta filtrar a algunos basofilos: en teoria clasificar_y_filtrar_linfocitos los filtra por la"
" solidez del nucleo pero hay algunos que no son eliminados correctamente, al intentar subir el"
" valor de solidez deberia eliminarlos pero tambien elimina algunos linfocitos"
# Out:
# ' valor de solidez deberia eliminarlos pero tambien elimina algunos linfocitos'

# %%
import pandas as pd
from pathlib import Path

# 1. Cargar imágenes válidas desde JSON
dataset, rutas_todas = obtener_rutas_imagenes()

print(f'\nTotal de imágenes a procesar: {len(rutas_todas)}')
print('Iniciando pipeline...\n')

base_datos_celulas = []
ok, errores = 0, 0

# ========================================================
# MOTOR PRINCIPAL
# Nota: rutas_todas[0:5] procesa solo 5 imágenes de prueba.
# Para procesar todas: for ruta in rutas_todas:
# ========================================================
for ruta in rutas_todas[0:10]:
    try:
        # A. Preprocesamiento
        img_rgb, _, canal_filtrado = preprocesamiento(ruta, filtro='mediana', ksize=5)

        # B. Segmentación del núcleo
        masc_nuc = segmentar_nucleo_estricto(canal_filtrado)

        # C. Segmentación de la célula completa
        masc_cel_bruta, _ = segmentar_celula_otsu(canal_filtrado, umbral_maximo=45)
        _, _, masc_cel_limpia = refinar_mascara_nucleo(masc_cel_bruta, kernel_size=5)

        # D. Filtrado de linfocitos
        masc_final, img_limpia, caracteristicas = clasificar_y_filtrar_linfocitos(
            masc_cel_limpia, masc_nuc, img_rgb
        )

        # E. Guardar imagen procesada en resultados/Notebook2/
        guardar_imagen_resultado(
            img_limpia, ruta,
            carpeta_resultados='../data/resultados/Notebook2/'
        )

        # F. Registrar métricas
        for celula in caracteristicas:
            celula['Nombre_Archivo'] = ruta.name
            celula['Clase']          = ruta.parent.name
            base_datos_celulas.append(celula)

        ok += 1
        print(f'OK  {ruta.parent.name}/{ruta.name} | Células: {len(caracteristicas)}')

    except Exception as e:
        errores += 1
        print(f'ERR {ruta.name}: {e}')

# ========================================================
# GUARDAR MÉTRICAS EN CSV
# ========================================================
print(f'\nProcesadas: {ok} | Errores: {errores}')

if base_datos_celulas:
    df_resultados = pd.DataFrame(base_datos_celulas)
    csv_path = Path('../data/resultados/Notebook2/metricas_linfocitos.csv')
    csv_path.parent.mkdir(parents=True, exist_ok=True)
    df_resultados.to_csv(csv_path, index=False, encoding='utf-8')
    print(f'CSV guardado en: {csv_path}')
    print(df_resultados.head())
else:
    print('No se extrajeron células. Revisar pipeline.')
# Out:
# Dataset cargado:
#   Benign    : 504 imágenes
#   Early     : 985 imágenes
#   Pre       : 963 imágenes
#   Pro       : 804 imágenes
#   Total     : 3256 imágenes
#
# Total de imágenes a procesar: 3256
# Iniciando pipeline...
#
# OK  Benign/WBC-Benign-001.jpg | Células: 4
# OK  Benign/WBC-Benign-002.jpg | Células: 9
# OK  Benign/WBC-Benign-003.jpg | Células: 10
# OK  Benign/WBC-Benign-004.jpg | Células: 3
# OK  Benign/WBC-Benign-005.jpg | Células: 3
# OK  Benign/WBC-Benign-006.jpg | Células: 1
# OK  Benign/WBC-Benign-007.jpg | Células: 4
# OK  Benign/WBC-Benign-008.jpg | Células: 3
# OK  Benign/WBC-Benign-009.jpg | Células: 8
# OK  Benign/WBC-Benign-010.jpg | Células: 5
#
# Procesadas: 10 | Errores: 0
# CSV guardado en: ..\data\resultados\Notebook2\metricas_linfocitos.csv
#    Area_Celula  Solidez_Nuc  Circ_Nuc  Textura_Nuc      Nombre_Archivo   Clase
# 0        220.5         0.98      0.77        29.08  WBC-Benign-001.jpg  Benign
# 1        552.0         0.98      0.82        13.74  WBC-Benign-001.jpg  Benign
# 2        552.5         0.92      0.66        15.79  WBC-Benign-001.jpg  Benign
# 3        304.0         0.98      0.88        19.50  WBC-Benign-001.jpg  Benign
# 4       1000.0         0.94      0.73        20.36  WBC-Benign-002.jpg  Benign

# %%
# Contadores de control
ok = 0
errores = 0

print("--- Iniciando Pipeline de Segmentación ---")

for ruta in rutas_todas:
    try:
        # A. Preprocesamiento de canales
        img_rgb, _, canal_filtrado = preprocesamiento(ruta)
        
        # B. Segmentación del núcleo
        masc_nuc = segmentar_nucleo_estricto(canal_filtrado)
        
        # C. Segmentación celular + morfología asimétrica anti-siamesas
        masc_cel_bruta, _ = segmentar_celula_otsu(canal_filtrado, umbral_maximo=45)
        _, _, masc_cel_limpia = refinar_mascara_nucleo(masc_cel_bruta, kernel_size=5)
        
        # D. Filtrado definitivo aplicando la regla de oro
        masc_final, img_limpia, linfocitos_detectados = clasificar_y_filtrar_linfocitos(masc_cel_limpia, masc_nuc, img_rgb)
        
        # E. Guardado directo de la imagen recortada limpia
        guardar_imagen_resultado(img_limpia, ruta, carpeta_resultados='../data/resultados/Notebook3/')
        
        ok += 1
        print(f"✅ OK {ruta.parent.name}/{ruta.name} | Linfocitos filtrados: {len(linfocitos_detectados)}")
        
    except Exception as e:
        errores += 1
        print(f"❌ ERR en {ruta.name}: {e}")

print(f'\n--- ¡Proceso terminado con éxito! ---')
print(f'✔️ Imágenes procesadas de forma limpia: {ok}')
print(f'❌ Errores en la iteración: {errores}')
# Out:
# --- Iniciando Pipeline de Segmentación ---
# ✅ OK Benign/WBC-Benign-001.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-002.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-003.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-004.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-005.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-006.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-007.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-008.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-009.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-010.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-011.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-012.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-013.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-014.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-015.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-016.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-017.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-018.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-019.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-020.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-021.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-022.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-023.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-024.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-025.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-026.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-027.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-028.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-029.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-030.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-031.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-032.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-033.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-034.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-035.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-036.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-037.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-038.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-039.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-040.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-041.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-042.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-043.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-044.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-045.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-046.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-047.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-048.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-049.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-050.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-051.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-052.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-053.jpg | Linfocitos filtrados: 12
# ✅ OK Benign/WBC-Benign-054.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-055.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-056.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-057.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-058.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-059.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-060.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-061.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-062.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-063.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-064.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-065.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-066.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-067.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-068.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-069.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-070.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-071.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-072.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-073.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-074.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-075.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-076.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-077.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-078.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-079.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-080.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-081.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-082.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-083.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-084.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-085.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-086.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-087.jpg | Linfocitos filtrados: 11
# ✅ OK Benign/WBC-Benign-088.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-089.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-090.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-091.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-092.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-093.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-094.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-095.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-096.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-097.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-098.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-099.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-100.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-101.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-102.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-103.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-104.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-105.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-106.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-107.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-108.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-109.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-110.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-111.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-112.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-113.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-114.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-115.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-116.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-117.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-118.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-119.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-120.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-121.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-122.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-123.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-124.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-125.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-126.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-127.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-128.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-129.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-130.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-131.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-132.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-133.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-134.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-135.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-136.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-137.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-138.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-139.jpg | Linfocitos filtrados: 11
# ✅ OK Benign/WBC-Benign-140.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-141.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-142.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-143.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-144.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-145.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-146.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-147.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-148.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-149.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-150.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-151.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-152.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-153.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-154.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-155.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-156.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-157.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-158.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-159.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-160.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-161.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-162.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-163.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-164.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-165.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-166.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-167.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-168.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-169.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-170.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-171.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-172.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-173.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-174.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-175.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-176.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-177.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-178.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-179.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-180.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-181.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-182.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-183.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-184.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-185.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-186.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-187.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-188.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-189.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-190.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-191.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-192.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-193.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-194.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-195.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-196.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-197.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-198.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-199.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-200.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-201.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-202.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-203.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-204.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-205.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-206.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-207.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-208.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-209.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-210.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-211.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-212.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-213.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-214.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-215.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-216.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-217.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-218.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-219.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-220.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-221.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-222.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-223.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-224.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-225.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-226.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-227.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-228.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-229.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-230.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-231.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-232.jpg | Linfocitos filtrados: 15
# ✅ OK Benign/WBC-Benign-233.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-234.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-235.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-236.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-237.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-238.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-239.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-240.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-241.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-242.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-243.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-244.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-245.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-246.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-247.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-248.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-249.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-250.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-251.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-252.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-253.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-254.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-255.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-256.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-257.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-258.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-259.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-260.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-261.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-262.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-263.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-264.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-265.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-266.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-267.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-268.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-269.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-270.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-271.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-272.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-273.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-274.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-275.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-276.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-277.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-278.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-279.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-280.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-281.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-282.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-283.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-284.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-285.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-286.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-287.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-288.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-289.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-290.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-291.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-292.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-293.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-294.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-295.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-296.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-297.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-298.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-299.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-300.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-301.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-302.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-303.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-304.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-305.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-306.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-307.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-308.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-309.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-310.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-311.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-312.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-313.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-314.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-315.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-316.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-317.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-318.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-319.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-320.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-321.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-322.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-323.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-324.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-325.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-326.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-327.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-328.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-329.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-330.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-331.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-332.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-333.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-334.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-335.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-336.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-337.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-338.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-339.jpg | Linfocitos filtrados: 11
# ✅ OK Benign/WBC-Benign-340.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-341.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-342.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-343.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-344.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-345.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-346.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-347.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-348.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-349.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-350.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-351.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-352.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-353.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-354.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-355.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-356.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-357.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-358.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-359.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-360.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-361.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-362.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-363.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-364.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-365.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-366.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-367.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-368.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-369.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-370.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-371.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-372.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-373.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-374.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-375.jpg | Linfocitos filtrados: 13
# ✅ OK Benign/WBC-Benign-376.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-377.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-378.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-379.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-380.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-381.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-382.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-383.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-384.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-385.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-386.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-387.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-388.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-389.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-390.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-391.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-392.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-393.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-394.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-395.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-396.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-397.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-398.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-399.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-400.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-401.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-402.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-403.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-404.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-405.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-406.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-407.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-408.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-409.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-410.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-411.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-412.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-413.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-414.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-415.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-416.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-417.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-418.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-419.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-420.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-421.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-422.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-423.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-424.jpg | Linfocitos filtrados: 10
# ✅ OK Benign/WBC-Benign-425.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-426.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-427.jpg | Linfocitos filtrados: 9
# ✅ OK Benign/WBC-Benign-428.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-429.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-430.jpg | Linfocitos filtrados: 11
# ✅ OK Benign/WBC-Benign-431.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-432.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-433.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-434.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-435.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-436.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-437.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-438.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-439.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-440.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-441.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-442.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-443.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-444.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-445.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-446.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-447.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-448.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-449.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-450.jpg | Linfocitos filtrados: 8
# ✅ OK Benign/WBC-Benign-451.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-452.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-453.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-454.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-455.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-456.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-457.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-458.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-459.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-460.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-461.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-462.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-463.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-464.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-465.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-466.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-467.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-468.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-469.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-470.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-471.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-472.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-473.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-474.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-475.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-476.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-477.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-478.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-479.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-480.jpg | Linfocitos filtrados: 7
# ✅ OK Benign/WBC-Benign-481.jpg | Linfocitos filtrados: 6
# ✅ OK Benign/WBC-Benign-482.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-483.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-484.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-485.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-486.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-487.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-488.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-489.jpg | Linfocitos filtrados: 5
# ✅ OK Benign/WBC-Benign-490.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-491.jpg | Linfocitos filtrados: 0
# ✅ OK Benign/WBC-Benign-492.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-493.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-494.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-495.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-496.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-497.jpg | Linfocitos filtrados: 1
# ✅ OK Benign/WBC-Benign-498.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-499.jpg | Linfocitos filtrados: 4
# ✅ OK Benign/WBC-Benign-500.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-501.jpg | Linfocitos filtrados: 3
# ✅ OK Benign/WBC-Benign-502.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-503.jpg | Linfocitos filtrados: 2
# ✅ OK Benign/WBC-Benign-504.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-001.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-002.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-003.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-004.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-005.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-006.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-007.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-008.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-009.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-010.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-011.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-012.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-013.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-014.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-015.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-016.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-017.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-018.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-019.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-020.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-021.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-022.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-023.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-024.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-025.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-026.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-027.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-028.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-029.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-030.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-031.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-032.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-033.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-034.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-035.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-036.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-037.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-038.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-039.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-040.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-041.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-042.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-043.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-044.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-045.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-046.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-047.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-048.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-049.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-050.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-051.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-052.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-053.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-054.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-055.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-056.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-057.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-058.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-059.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-060.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-061.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-062.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-063.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-064.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-065.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-066.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-067.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-068.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-069.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-070.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-071.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-072.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-073.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-074.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-075.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-076.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-077.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-078.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-079.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-080.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-081.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-082.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-083.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-084.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-085.jpg | Linfocitos filtrados: 8
# ✅ OK Early/WBC-Malignant-Early-086.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-087.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-088.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-089.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-090.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-091.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-092.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-093.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-094.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-095.jpg | Linfocitos filtrados: 8
# ✅ OK Early/WBC-Malignant-Early-096.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-097.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-098.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-099.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-100.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-101.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-102.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-103.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-104.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-105.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-106.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-107.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-108.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-109.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-110.jpg | Linfocitos filtrados: 8
# ✅ OK Early/WBC-Malignant-Early-111.jpg | Linfocitos filtrados: 9
# ✅ OK Early/WBC-Malignant-Early-112.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-113.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-114.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-115.jpg | Linfocitos filtrados: 11
# ✅ OK Early/WBC-Malignant-Early-116.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-117.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-118.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-119.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-120.jpg | Linfocitos filtrados: 12
# ✅ OK Early/WBC-Malignant-Early-121.jpg | Linfocitos filtrados: 8
# ✅ OK Early/WBC-Malignant-Early-122.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-123.jpg | Linfocitos filtrados: 8
# ✅ OK Early/WBC-Malignant-Early-124.jpg | Linfocitos filtrados: 12
# ✅ OK Early/WBC-Malignant-Early-125.jpg | Linfocitos filtrados: 9
# ✅ OK Early/WBC-Malignant-Early-126.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-127.jpg | Linfocitos filtrados: 9
# ✅ OK Early/WBC-Malignant-Early-128.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-129.jpg | Linfocitos filtrados: 11
# ✅ OK Early/WBC-Malignant-Early-130.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-131.jpg | Linfocitos filtrados: 11
# ✅ OK Early/WBC-Malignant-Early-132.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-133.jpg | Linfocitos filtrados: 9
# ✅ OK Early/WBC-Malignant-Early-134.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-135.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-136.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-137.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-138.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-139.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-140.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-141.jpg | Linfocitos filtrados: 8
# ✅ OK Early/WBC-Malignant-Early-142.jpg | Linfocitos filtrados: 9
# ✅ OK Early/WBC-Malignant-Early-143.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-144.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-145.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-146.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-147.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-148.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-149.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-150.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-151.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-152.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-153.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-154.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-155.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-156.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-157.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-158.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-159.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-160.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-161.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-162.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-163.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-164.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-165.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-166.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-167.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-168.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-169.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-170.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-171.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-172.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-173.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-174.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-175.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-176.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-177.jpg | Linfocitos filtrados: 7
# ✅ OK Early/WBC-Malignant-Early-178.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-179.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-180.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-181.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-182.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-183.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-184.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-185.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-186.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-187.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-188.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-189.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-190.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-191.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-192.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-193.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-194.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-195.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-196.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-197.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-198.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-199.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-200.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-201.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-202.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-203.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-204.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-205.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-206.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-207.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-208.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-209.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-210.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-211.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-212.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-213.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-214.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-215.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-216.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-217.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-218.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-219.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-220.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-221.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-222.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-223.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-224.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-225.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-226.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-227.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-228.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-229.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-230.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-231.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-232.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-233.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-234.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-235.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-236.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-237.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-238.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-239.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-240.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-241.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-242.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-243.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-244.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-245.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-246.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-247.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-248.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-249.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-250.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-251.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-252.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-253.jpg | Linfocitos filtrados: 9
# ✅ OK Early/WBC-Malignant-Early-254.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-255.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-256.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-257.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-258.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-259.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-260.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-261.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-262.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-263.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-264.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-265.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-266.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-267.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-268.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-269.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-270.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-271.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-272.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-273.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-274.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-275.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-276.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-277.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-278.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-279.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-280.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-281.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-282.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-283.jpg | Linfocitos filtrados: 4
# ✅ OK Early/WBC-Malignant-Early-284.jpg | Linfocitos filtrados: 1
# ✅ OK Early/WBC-Malignant-Early-285.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-286.jpg | Linfocitos filtrados: 13
# ✅ OK Early/WBC-Malignant-Early-287.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-288.jpg | Linfocitos filtrados: 5
# ✅ OK Early/WBC-Malignant-Early-289.jpg | Linfocitos filtrados: 3
# ✅ OK Early/WBC-Malignant-Early-290.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-291.jpg | Linfocitos filtrados: 10
# ✅ OK Early/WBC-Malignant-Early-292.jpg | Linfocitos filtrados: 2
# ✅ OK Early/WBC-Malignant-Early-293.jpg | Linfocitos filtrados: 0
# ✅ OK Early/WBC-Malignant-Early-294.jpg | Linfocitos filtrados: 6
# ✅ OK Early/WBC-Malignant-Early-295.jpg | Linfocitos filtrados: 5
# ...
# ✅ OK Pro/WBC-Malignant-Pro-547.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-548.jpg | Linfocitos filtrados: 18
# ✅ OK Pro/WBC-Malignant-Pro-549.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-550.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-551.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-552.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-553.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-554.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-555.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-556.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-557.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-558.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-559.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-560.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-561.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-562.jpg | Linfocitos filtrados: 18
# ✅ OK Pro/WBC-Malignant-Pro-563.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-564.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-565.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-566.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-567.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-568.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-569.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-570.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-571.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-572.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-573.jpg | Linfocitos filtrados: 5
# ✅ OK Pro/WBC-Malignant-Pro-574.jpg | Linfocitos filtrados: 5
# ✅ OK Pro/WBC-Malignant-Pro-575.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-576.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-577.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-578.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-579.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-580.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-581.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-582.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-583.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-584.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-585.jpg | Linfocitos filtrados: 3
# ✅ OK Pro/WBC-Malignant-Pro-586.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-587.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-588.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-589.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-590.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-591.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-592.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-593.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-594.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-595.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-596.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-597.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-598.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-599.jpg | Linfocitos filtrados: 5
# ✅ OK Pro/WBC-Malignant-Pro-600.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-601.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-602.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-603.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-604.jpg | Linfocitos filtrados: 17
# ✅ OK Pro/WBC-Malignant-Pro-605.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-606.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-607.jpg | Linfocitos filtrados: 17
# ✅ OK Pro/WBC-Malignant-Pro-608.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-609.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-610.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-611.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-612.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-613.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-614.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-615.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-616.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-617.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-618.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-619.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-620.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-621.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-622.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-623.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-624.jpg | Linfocitos filtrados: 17
# ✅ OK Pro/WBC-Malignant-Pro-625.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-626.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-627.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-628.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-629.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-630.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-631.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-632.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-633.jpg | Linfocitos filtrados: 5
# ✅ OK Pro/WBC-Malignant-Pro-634.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-635.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-636.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-637.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-638.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-639.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-640.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-641.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-642.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-643.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-644.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-645.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-646.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-647.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-648.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-649.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-650.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-651.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-652.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-653.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-654.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-655.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-656.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-657.jpg | Linfocitos filtrados: 3
# ✅ OK Pro/WBC-Malignant-Pro-658.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-659.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-660.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-661.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-662.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-663.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-664.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-665.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-666.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-667.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-668.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-669.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-670.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-671.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-672.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-673.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-674.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-675.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-676.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-677.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-678.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-679.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-680.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-681.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-682.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-683.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-684.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-685.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-686.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-687.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-688.jpg | Linfocitos filtrados: 5
# ✅ OK Pro/WBC-Malignant-Pro-689.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-690.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-691.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-692.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-693.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-694.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-695.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-696.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-697.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-698.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-699.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-700.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-701.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-702.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-703.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-704.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-705.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-706.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-707.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-708.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-709.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-710.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-711.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-712.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-713.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-714.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-715.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-716.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-717.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-718.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-719.jpg | Linfocitos filtrados: 15
# ✅ OK Pro/WBC-Malignant-Pro-720.jpg | Linfocitos filtrados: 16
# ✅ OK Pro/WBC-Malignant-Pro-721.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-722.jpg | Linfocitos filtrados: 16
# ✅ OK Pro/WBC-Malignant-Pro-723.jpg | Linfocitos filtrados: 20
# ✅ OK Pro/WBC-Malignant-Pro-724.jpg | Linfocitos filtrados: 16
# ✅ OK Pro/WBC-Malignant-Pro-725.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-726.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-727.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-728.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-729.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-730.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-731.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-732.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-733.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-734.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-735.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-736.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-737.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-738.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-739.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-740.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-741.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-742.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-743.jpg | Linfocitos filtrados: 5
# ✅ OK Pro/WBC-Malignant-Pro-744.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-745.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-746.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-747.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-748.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-749.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-750.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-751.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-752.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-753.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-754.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-755.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-756.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-757.jpg | Linfocitos filtrados: 4
# ✅ OK Pro/WBC-Malignant-Pro-758.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-759.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-760.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-761.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-762.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-763.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-764.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-765.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-766.jpg | Linfocitos filtrados: 16
# ✅ OK Pro/WBC-Malignant-Pro-767.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-768.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-769.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-770.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-771.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-772.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-773.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-774.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-775.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-776.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-777.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-778.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-779.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-780.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-781.jpg | Linfocitos filtrados: 14
# ✅ OK Pro/WBC-Malignant-Pro-782.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-783.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-784.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-785.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-786.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-787.jpg | Linfocitos filtrados: 6
# ✅ OK Pro/WBC-Malignant-Pro-788.jpg | Linfocitos filtrados: 12
# ✅ OK Pro/WBC-Malignant-Pro-789.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-790.jpg | Linfocitos filtrados: 7
# ✅ OK Pro/WBC-Malignant-Pro-791.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-792.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-793.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-794.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-795.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-796.jpg | Linfocitos filtrados: 13
# ✅ OK Pro/WBC-Malignant-Pro-797.jpg | Linfocitos filtrados: 9
# ✅ OK Pro/WBC-Malignant-Pro-798.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-799.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-800.jpg | Linfocitos filtrados: 3
# ✅ OK Pro/WBC-Malignant-Pro-801.jpg | Linfocitos filtrados: 10
# ✅ OK Pro/WBC-Malignant-Pro-802.jpg | Linfocitos filtrados: 11
# ✅ OK Pro/WBC-Malignant-Pro-803.jpg | Linfocitos filtrados: 8
# ✅ OK Pro/WBC-Malignant-Pro-804.jpg | Linfocitos filtrados: 8
#
# --- ¡Proceso terminado con éxito! ---
# ✔️ Imágenes procesadas de forma limpia: 3256
# ❌ Errores en la iteración: 0

# %%
import cv2
import numpy as np
from pathlib import Path

# Configuración de las rutas
RESULT_PATH = Path('../data/resultados/Notebook3')
CLASSES = ['Benign', 'Early', 'Pre', 'Pro']

estadisticas = {
    'Benign': {'total': 0, 'cancerigenas': 0},
    'Early': {'total': 0, 'cancerigenas': 0},
    'Pre': {'total': 0, 'cancerigenas': 0},
    'Pro': {'total': 0, 'cancerigenas': 0}
}

UMBRAL_NC = 0.75 

print("--- Iniciando Clasificación de Leucemia (Relación N/C Adaptativa) ---")

for clase in CLASSES:
    carpeta_clase = RESULT_PATH / clase
    imagenes = list(carpeta_clase.glob('*.jpg')) + list(carpeta_clase.glob('*.png'))
    
    estadisticas[clase]['total'] = len(imagenes)
    
    for ruta in imagenes:
        img_bgr = cv2.imread(str(ruta))
        img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
        img_gris = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
        
        # Máscara de la Célula entera (El fondo negro nos regala la máscara)
        _, masc_celula = cv2.threshold(img_gris, 10, 255, cv2.THRESH_BINARY)
        
        # Preparar el canal óptico para el núcleo
        img_lab = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2LAB)
        canal_b = img_lab[:, :, 2]
        canal_inv = cv2.bitwise_not(canal_b)
        clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8, 8))
        canal_optico = clahe.apply(canal_inv)
        
        contornos_celula, _ = cv2.findContours(masc_celula, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        imagen_es_cancerigena = False
        
        for cnt in contornos_celula:
            area_celula = cv2.contourArea(cnt)
            if area_celula < 1000: continue 
            
            # Aislar solo el sector de la imagen que pertenece a ESTA célula
            mask_esta_celula = np.zeros_like(masc_celula)
            cv2.drawContours(mask_esta_celula, [cnt], -1, 255, thickness=cv2.FILLED)
            
            # ==========================================================
            # LA MAGIA: Otsu Local (Adaptativo a la coloración de la célula)
            # ==========================================================
            # Extraemos solo los valores de los píxeles que están dentro de la célula
            pixeles_celula = canal_optico[mask_esta_celula == 255]
            
            if len(pixeles_celula) > 0:
                # Otsu calcula el punto de corte ideal solo evaluando los tonos de esa célula
                umbral_otsu, _ = cv2.threshold(pixeles_celula, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
                
                # Aplicamos el umbral adaptativo
                _, nucleo_binario = cv2.threshold(canal_optico, umbral_otsu, 255, cv2.THRESH_BINARY)
                
                # Nos aseguramos de que no desborde la célula
                nucleo_aislado = cv2.bitwise_and(nucleo_binario, nucleo_binario, mask=mask_esta_celula)
                
                contornos_nuc, _ = cv2.findContours(nucleo_aislado, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                
                if len(contornos_nuc) > 0:
                    cnt_nucleo = max(contornos_nuc, key=cv2.contourArea)
                    area_nucleo = cv2.contourArea(cnt_nucleo)
                    
                    # Cálculo de la Relación N/C
                    ratio_nc = area_nucleo / area_celula
                    
                    if ratio_nc > UMBRAL_NC:
                        imagen_es_cancerigena = True
                        break 
                        
        if imagen_es_cancerigena:
            estadisticas[clase]['cancerigenas'] += 1

# Imprimir Resultados
print("\n📊 RESULTADOS FINALES DE CLASIFICACIÓN (Relación N/C > 0.75):")
for clase in CLASSES:
    totales = estadisticas[clase]['total']
    cancer = estadisticas[clase]['cancerigenas']
    porcentaje = (cancer / totales * 100) if totales > 0 else 0
    
    print(f"🔸 Carpeta {clase.upper()}:")
    print(f"   - Imágenes válidas procesadas: {totales}")
    print(f"   - Diagnosticadas con cáncer: {cancer} ({porcentaje:.1f}%)")
    print("-" * 40)
# Out:
# --- Iniciando Clasificación de Leucemia (Relación N/C Adaptativa) ---
#
# 📊 RESULTADOS FINALES DE CLASIFICACIÓN (Relación N/C > 0.75):
# 🔸 Carpeta BENIGN:
#    - Imágenes válidas procesadas: 504
#    - Diagnosticadas con cáncer: 0 (0.0%)
# ----------------------------------------
# 🔸 Carpeta EARLY:
#    - Imágenes válidas procesadas: 985
#    - Diagnosticadas con cáncer: 0 (0.0%)
# ----------------------------------------
# 🔸 Carpeta PRE:
#    - Imágenes válidas procesadas: 963
#    - Diagnosticadas con cáncer: 0 (0.0%)
# ----------------------------------------
# 🔸 Carpeta PRO:
#    - Imágenes válidas procesadas: 804
#    - Diagnosticadas con cáncer: 0 (0.0%)
# ----------------------------------------

# %%
# Probar con una imagen Early
cls = 'Early'
ruta_imagen = list((RAW_PATH / cls).glob('*.jpg'))[2]

img_rgb, canal_s_raw, canal_proc = preprocesamiento(ruta_imagen, filtro='mediana', ksize=5)
mascara_nucleos = segmentar_nucleo_estricto(canal_proc)
mascara_filtrada, img_limpia, datos = clasificar_y_filtrar_linfocitos(mask_raw, mascara_nucleos, img_rgb)

fig, axs = plt.subplots(1, 4, figsize=(20, 5))
axs[0].imshow(img_rgb);                        axs[0].set_title('Original Early');     axs[0].axis('off')
axs[1].imshow(canal_proc, cmap='gray');        axs[1].set_title('Canal S procesado');  axs[1].axis('off')
axs[2].imshow(mascara_nucleos, cmap='gray');   axs[2].set_title('Máscara núcleo');     axs[2].axis('off')
axs[3].imshow(mascara_filtrada, cmap='gray');  axs[3].set_title('Filtrado final');     axs[3].axis('off')
plt.tight_layout()
plt.show()
print(pd.DataFrame(datos))
# Out:
#    Area_Celula  Solidez_Nuc  Circ_Nuc  Textura_Nuc
# 0        527.0         0.89      0.70        23.76
# 1        307.0         0.94      0.72         7.33
